# %%
from scripts.data_loader import load_data
from scripts.data_preprocessing import preprocess_data
from scripts.pca_analysis import apply_pca
from scripts.clustering import apply_kmeans
from scripts.visualization import *
from scripts.one_hot_encoder import one_hot_encoder

# %%
if df is not None:
    dp = one_hot_encoder(file_path)

    scaled_data = preprocess_data(dp)

    pca_data = apply_pca(scaled_data, n_components=30)

    # plot_pca(pca_data)

    clusters = apply_kmeans(pca_data, n_clusters=4)

    plot_clusters(pca_data, clusters)
# Out:
# one hot encoding performed successfully
# Data loaded successfully! Shape: (600, 43)
# Data preprocessing complete. Shape: (600, 43)
# Explained variance by components: [0.12777085 0.10346686 0.07191641 0.05240989 0.05008921 0.04217265
#  0.0396507  0.03837371 0.03579573 0.03456356 0.02973409 0.02938796
#  0.0258209  0.02560848 0.02479335 0.02346393 0.02254585 0.0209035
#  0.02008867 0.01951796 0.01739045 0.01728692 0.01644819 0.01433426
#  0.01409023 0.01251387 0.01147002 0.0108297  0.01058189 0.00868336]
# Total explained variance: 97.17%
# Explained variance by PC1: 0.12777085283905765
# Explained variance by PC2: 0.10346685603594123
# K-Means clustering completed with 4 clusters.
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# Out:
# [0]
# [1]
# [2]
